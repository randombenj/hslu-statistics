# %% [markdown]
# Die monatlichen Aufwendungen X [CHF] für den Wasserverbrauch eines 2-Personen-haushalts seien durch eine Zufallsvariable mit der folgenden Wahrscheinlichkeits-dichtefunktion gegeben:
# ![image.png](attachment:image.png)

# %% [markdown]
# a) Welchen Wert muss `c` annehmen?

# %% [markdown]
# b)  Geben Sie die Verteilungsfunktion F der Zufallsvariablen X an.

# %% [markdown]
# c) Welcher Wert der Aufwendungen wirdnur mit 10 % Wahrscheinlichkeit überschritten?

# %% [markdown]
# d) Wie hoch sind die erwarteten monatlichen Aufwendungen für den Wasserverbrauch eines 2-Personenhaushalts?
