# %% [markdown]
# Monte Carlo Algorithmen sind randomisierte Algorithmen und stellen ein gutes Werkzeug für Simulationen von stochastischen Prozessen dar.  Auch die Zahlπlässt sich mit Hilfe von Monte  Carlo Simulationen  bestimmen. Im Folgenden möchten wir ein Computerprogramm erstellen,  mit welchem man die Zahlπaufgrund von MonteCarlo Methoden simulieren kann. Man generiert hierzu zufällige Punkte
# ![image.png](attachment:image.png)
# und überprüft, ob diese innerhalb des Einheitskreises  mit Kreismittelpunkt MK=(0, 0)und Radius r=1 liegen. Die sich ergebende Wahrscheinlichkeitsverteilung P\[(x,y)∈Kreis\] stellt die Fläche eines Viertels des Einheitskreises dar. π kann nun mit folgender Formel berechnet werden
# ![Screenshot_2019-10-04%20serie_3%20pdf%20-%20goto%20php.png](attachment:Screenshot_2019-10-04%20serie_3%20pdf%20-%20goto%20php.png)
# ![Screenshot_2019-10-04%20serie_3%20pdf%20-%20goto%20php%281%29.png](attachment:Screenshot_2019-10-04%20serie_3%20pdf%20-%20goto%20php%281%29.png)
#
# Bestimmen Sie mit Hilfe dieser Überlegung die Zahl π. Python-Hinweise:
#
# ```
# # Generieren von 100 gleichmaessig verteilten
# # Zufallszahlen im Intervall [-1,1]
# from scipy.stats import uniform
# import numpy as npx=uniform.rvs(size=100, loc=-1, scale=2)
# # Bestimmen der Anzahl Zahlen kleiner als eins; Beispiel:
# # Anzahl von 100 zufaellig im Intervall [0,10] generierten
# # Zahlen, die kleiner als 1 sind:
# np.sum(x<1)
# ```
