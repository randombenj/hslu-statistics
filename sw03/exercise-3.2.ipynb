# %% [markdown]
# In der Stadt Luzern gibt es bekanntlich viele Baustellen. Die Dauer X der Arbeiten bei einer Baustelle liege zwischen 0 und 20 Wochen. Die Dichte f(x) habe die folgende Form.
# ![image.png](attachment:image.png)

# %% [markdown]
# a) Begründen Sie, warum c=0.1 ist und schreiben Sie die Dichte f(x) explizit auf.

# %% [markdown]
# b) Berechnen Sie die Wahrscheinlichkeit, dass die Bauzeit X weniger als **5** && **10** Wochen beträgt.

# %% [markdown]
# c) Skizzieren Sie die kumulative Verteilungsfunktion

# %% [markdown]
# d) Berechnen Sie den Erwartungswert, den Median und die Standardabweichungder Dauer X.

# %% [markdown]
# e) K=40′000·√X entspreche dem Betrag in Franken, den die Arbeiten bei einerBaustelle kosten. Wie gross  ist die Wahrscheinlichkeit, dass die Arbeiten bei einer Baustelle höchstens 120’000.- Fr. kosten?

# %% [markdown]
# Die vorgeschlagene Verteilung ist nur ein Modell.  Man könnte die Dauer der Bauar-beiten zum Beispiel auch als exponentialverteilt annehmen

# %% [markdown]
# f) Für welchen Parameter λ hat die Exponentialverteilung denselben Erwartungswert wie die bisherige angenommene Verteilung?

# %% [markdown]
# g) Berechnen Sie mit der gefundenen Exponentialverteilung nochmals Teilaufgabe e).
