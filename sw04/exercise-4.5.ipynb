# %% [markdown]
# Wir betrachten einen Datensatz, bei welchem zwei Methoden zur Bestimmung der latenten Schmelzwärme von Eis verglichen werden. Wiederholte Messungen der freigesetzten Wärme beim Übergang von Eis bei −0.7℃ zu Wasser bei 0℃ ergaben die folgenden Werte (in cal/g):
#
# ![image.png](attachment:image.png)

# %%
methode_a = [79.98, 80.04, 80.02, 80.04, 80.03, 80.03, 80.04, 79.97, 80.05]
methode_b = [80.03, 80.02, 80.00, 80.02]
methode_c = [80.02, 79.94, 79.98, 79.97, 79.97, 80.03, 79.95, 79.97]

# %% [markdown]
# a) Berechnen Sie die arithmetischen Mittelwerte der beiden Methoden und geben Sie für jede Methode den absoluten Fehler an.

# %% [markdown]
# b) Wie lauten die relativen Fehler?
